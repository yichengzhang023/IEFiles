# %%
import pandas as pd
import json

# %%
toilet = pd.read_csv("./Public_toilets.csv")

# %%
toilet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 8 columns):
# name          74 non-null object
# female        74 non-null object
# male          74 non-null object
# wheelchair    74 non-null object
# operator      74 non-null object
# baby_facil    74 non-null object
# lat           74 non-null float64
# lon           74 non-null float64
# dtypes: float64(2), object(6)
# memory usage: 4.7+ KB

# %%
toilet[(toilet.baby_facil == 'yes')] #filter toliet without female's
# Out:
#                                                  name female male wheelchair  \
# 13  Public Toilet - Queen Victoria Market (465 Que...    yes  yes        yes
# 39  Public Toilet - Toilet 181 - Point Park (Point...    yes  yes        yes
# 42  Public Toilet - Town Hall Melbourne (200 Colli...    yes  yes        yes
# 50  Public Toilet - Toilet 182 - Docklands Park So...    yes  yes        yes
# 66  Public Toilet - Toilet 109 - Kings Domain Myer...    yes  yes        yes
#
#              operator baby_facil        lat         lon
# 13  City of Melbourne        yes -37.807864  144.957948
# 39  City of Melbourne        yes -37.823311  144.941828
# 42  City of Melbourne        yes -37.815216  144.966943
# 50  City of Melbourne        yes -37.821759  144.947383
# 66  City of Melbourne        yes -37.822892  144.975281

# %%
toilet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 8 columns):
# name          74 non-null object
# female        74 non-null object
# male          74 non-null object
# wheelchair    74 non-null object
# operator      74 non-null object
# baby_facil    74 non-null object
# lat           74 non-null float64
# lon           74 non-null float64
# dtypes: float64(2), object(6)
# memory usage: 4.7+ KB

# %%
toilet.drop('female',axis=1,inplace=True)
toilet.drop('male',axis=1,inplace=True)
toilet.drop('wheelchair',axis=1,inplace=True)
toilet.drop('operator',axis=1,inplace=True)
toilet.drop('baby_facil',axis=1,inplace=True)

# %%
with open('./toilets.json', 'w') as f:
    f.write(toilet.to_json(orient='records'))

# %%
toilet
# Out:
#                                                  name        lat         lon
# 0   Public Toilet - Queen Victoria Market (153 Vic... -37.806121  144.956538
# 1   Public Toilet - Victoria Harbour, Shed 3 (Nort... -37.819796  144.937665
# 2   Public Toilet - Victoria Harbour, Shed 2 (Nort... -37.818924  144.934239
# 3   Public Toilet - Toilet 169 - Batman Park (2A S... -37.821721  144.955578
# 4   Public Toilet - Toilet 102 - Fawkner Park, Nor... -37.840148  144.981383
# 5   Public Toilet - Toilet 173 - JJ Holland Park, ... -37.798064  144.921106
# 6   Public Toilet - Toilet 137 - Faraday Street (O... -37.798710  144.967594
# 7   Public Toilet - Toilet 105 -Sturt Street Reser... -37.830133  144.965012
# 8   Public Toilet - Toilet 131 - Royal Park (Flemi... -37.790174  144.943669
# 9   Public Toilet - Toilet 11 - Lonsdale Street (O... -37.810036  144.969902
# 10  Public Toilet - Toilet 119 - Fitzroy Gardens T... -37.812032  144.983080
# ...
